# %%
import numpy as np
import pandas as pd
from numpy import *
from numpy import linalg as la
import scipy
from scipy import sparse
from scipy.sparse import *
from scipy.sparse.linalg import svds
df=pd.read_csv("anonymous-msweb.test.txt",sep=',',names=['0','1','2','3'])
df2 = df.values

# %%
at = []
for i in range(len(df)):
    if df2[i][0] == 'A':
        at.append(df2[i][:2])

# %%
C_V =[]
for i in range(len(df)):
    if df2[i][0] == "C" or df2[i][0] == "V":
        C_V.append(df2[i][:2])

# %%
web = []
for i in range(len(at)):
    if int(at[i][1] not in web):
        web.append(int(at[i][1]))

# %%
web.sort()

# %%
users =[]
for i in range(len(C_V)):
    if C_V[i][0] == "C":
        if C_V[i][1] not in users:
            users.append(C_V[i][1])

# %%
data= []
for i in range(len(users)):
    data.append([0.0]*len(at))

# %%
df3 = pd.DataFrame(data,columns=web,index=users)

# %%
for i in range(len(C_V)):
    if C_V[i][0] == 'C':
        print("-----------")
        print("用戶:%d"%C_V[i][1])
        userid=C_V[i][1]
        temp = i+1
        while C_V[temp][0] == 'V':
            print('%d訪問的網站'%C_V[i][1],C_V[temp][1])
            df3.iloc[df3.index.get_loc(userid)][C_V[temp][1]] = 1.0
            temp = temp+1
            if temp == len(C_V):
                break
    i = i+temp
# Out:
# -----------
# 用戶:10001
# 10001訪問的網站 1038
# 10001訪問的網站 1026
# 10001訪問的網站 1034
# -----------
# 用戶:10002
# 10002訪問的網站 1008
# 10002訪問的網站 1056
# 10002訪問的網站 1032
# -----------
# 用戶:10003
# 10003訪問的網站 1064
# 10003訪問的網站 1065
# 10003訪問的網站 1020
# 10003訪問的網站 1007
# 10003訪問的網站 1038
# 10003訪問的網站 1026
# 10003訪問的網站 1052
# 10003訪問的網站 1041
# 10003訪問的網站 1028
# -----------
# 用戶:10004
# 10004訪問的網站 1004
# -----------
# 用戶:10005
# 10005訪問的網站 1017
# 10005訪問的網站 1156
# 10005訪問的網站 1004
# 10005訪問的網站 1018
# 10005訪問的網站 1008
# 10005訪問的網站 1027
# 10005訪問的網站 1009
# 10005訪問的網站 1046
# 10005訪問的網站 1038
# 10005訪問的網站 1006
# 10005訪問的網站 1026
# 10005訪問的網站 1052
# 10005訪問的網站 1060
# 10005訪問的網站 1001
# 10005訪問的網站 1041
# 10005訪問的網站 1034
# -----------
# 用戶:10006
# 10006訪問的網站 1034
# 10006訪問的網站 1004
# -----------
# 用戶:10007
# 10007訪問的網站 1008
# 10007訪問的網站 1000
# 10007訪問的網站 1035
# 10007訪問的網站 1016
# 10007訪問的網站 1031
# 10007訪問的網站 1003
# 10007訪問的網站 1034
# 10007訪問的網站 1018
# -----------
# 用戶:10008
# 10008訪問的網站 1065
# 10008訪問的網站 1123
# ...

# %%
res = np.mat(df3)
len(res)
# Out:
# 5000

# %%
U,Sigma,VT=scipy.sparse.linalg.svds(res)

# %%
# 对Sigma中的值求平方
Sig2=Sigma**2
# 计算总能量
print(sum(Sig2))
# 计算总能量的90%
print(sum(Sig2)*0.9)
# 计算前三个元素所包含的能量
print(sum(Sig2[:3]))
# 前三个元素所包含的能量低于总能量的90%，于是反覆计算到前六十四个刚好超过90%
print(sum(Sig2[:6]))
# Out:
# 7681.272528496173
# 6913.145275646556
# 2144.448287131754
# 7681.272528496173

# %%
from numpy import *
from numpy import linalg as la
# inA和inB都是列向量
def ecludSim(inA, inB) :
    return 1.0/(1.0 + la.norm(inA - inB))

def pearsSim(inA, inB) :
    # 检查是否存在三个或更多的点，若不存在，则返回1.0，这是因为此时两个向量完全相关
    if len(inA) < 3 : return 1.0
    return 0.5+0.5*corrcoef(inA, inB, rowvar = 0)[0][1]

def cosSim(inA, inB) :
    num = float(inA.T*inB)
    denom = la.norm(inA)*la.norm(inB)
    return 0.5+0.5*(num/denom)

# 基于SVD的评分估计
# 在recommend()中，svdEst用户替换对standEst()的调用，该函数对给定用户物品构建一个评分估计值。
# 与standEst()非常相似，不同之处就在于它在第64行对数据集进行了SVD分解。在SVD分解后，只利用包含
# 90%能量值的奇异值，这些奇异值以Numpy数组的形式得以保存。
def svdEst(dataMat, user, simMeas, item) :
    n = shape(dataMat)[1]
    simTotal = 0.0; ratSimTotal = 0.0
    U,Sigma,VT = la.svd(dataMat)
    # 使用奇异值构建一个对角矩阵
    Sig4 = mat(eye(7)*Sigma[:7])
    # 利用U矩阵将物品转换到低维空间中
    xformedItems = dataMat.T * U[:, :7] * Sig4.I
    # 对于给定的用户，for循环在用户对应行的所有元素上进行遍历，与standEst()函数中的for循环目的一样
    # 不同的是，这里的相似度是在低维空间下进行的。相似度的计算方法也会作为一个参数传递给该函数
    for j in range(n) :
        userRating = dataMat[user,j]
        if userRating == 0 or j == item : continue
        similarity = simMeas(xformedItems[item, :].T, xformedItems[j, :].T)
        # print便于了解相似度计算的进展情况
        print ('the %d and %d similarity is : %f' % (item, j, similarity))
        # 对相似度求和
        simTotal += similarity
        # 对相似度及评分值的乘积求和
        ratSimTotal += similarity * userRating
    if simTotal == 0 : return 0
    else : return ratSimTotal/simTotal

# 推荐引擎，会调用svdEst()函数，产生最高的N个推荐结果。
# simMeas：相似度计算方法
# estMethod：估计方法
def recommend(dataMat, user, N=10, simMeas=cosSim, estMethod=svdEst) :
    # 寻找未评级的物品，对给定用户建立一个未评分的物品列表
    unratedItems = nonzero(dataMat[user, :].A==0)[1]
    # 如果不存在未评分物品，退出函数，否则在所有未评分物品上进行循环
    if len(unratedItems) == 0 : return 'you rated everything'
    itemScores = []
    for item in unratedItems :
        # 对于每个未评分物品，通过调用svdEst()来产生该物品的预测评分。
        estimatedScore = estMethod(dataMat, user, simMeas, item)
        # 该物品的编号和估计得分值会放在一个元素列表itemScores
        itemScores.append((item, estimatedScore))
    # 寻找前N个未评级物品
    return  sorted(itemScores, key=lambda jj : jj[1], reverse=True)[:N]

# %%
recommend(res,100)
# Out:
# the 0 and 8 similarity is : 0.462067
# the 0 and 34 similarity is : 0.583037
# the 1 and 8 similarity is : 0.470513
# the 1 and 34 similarity is : 0.500636
# the 2 and 8 similarity is : 0.490709
# the 2 and 34 similarity is : 0.542973
# the 3 and 8 similarity is : 0.515713
# the 3 and 34 similarity is : 0.476758
# the 4 and 8 similarity is : 0.500611
# the 4 and 34 similarity is : 0.501489
# the 5 and 8 similarity is : 0.381979
# the 5 and 34 similarity is : 0.497422
# the 6 and 8 similarity is : 0.346748
# the 6 and 34 similarity is : 0.777733
# the 7 and 8 similarity is : 0.920372
# the 7 and 34 similarity is : 0.487653
# the 9 and 8 similarity is : 0.506491
# the 9 and 34 similarity is : 0.495732
# the 10 and 8 similarity is : 0.560992
# the 10 and 34 similarity is : 0.405476
# the 11 and 8 similarity is : 0.574573
# the 11 and 34 similarity is : 0.452060
# the 12 and 8 similarity is : 0.455240
# the 12 and 34 similarity is : 0.619134
# the 13 and 8 similarity is : 0.508659
# ...
